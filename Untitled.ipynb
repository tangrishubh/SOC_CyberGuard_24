# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Step 1: Load the dataset
data = pd.read_csv(r"C:\Users\shubh\OneDrive\Desktop\SOC_cyberguard\Train_data.csv")

# Step 2: Preprocess the data
# Check for missing values and fill them with 0
data.fillna(0, inplace=True)

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Step 3: Apply K-means clustering
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(scaled_data)
labels = kmeans.labels_

# Step 4: Analyze the clusters
# Add the cluster labels to the original data
data['Cluster'] = labels

# Assuming cluster 0 is normal and cluster 1 is anomaly
# You may need to check the characteristics of each cluster to confirm this assumption
data['Anomaly'] = data['Cluster'].apply(lambda x: 'Anomaly' if x == 1 else 'Normal')

# Step 5: Visualize the clusters using PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_data)
plt.figure(figsize=(10, 7))
plt.scatter(principal_components[:, 0], principal_components[:, 1], c=labels, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering of Network Packets')
plt.show()

# Print out the first few rows to see the results
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18376\4021851002.py in ?()
#      13 data.fillna(0, inplace=True)
#      14
#      15 # Standardize the data
#      16 scaler = StandardScaler()
# ---> 17 scaled_data = scaler.fit_transform(data)
#      18
#      19 # Step 3: Apply K-means clustering
#      20 kmeans = KMeans(n_clusters=2, random_state=42)
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     293     @wraps(f)
#     294     def wrapped(self, X, *args, **kwargs):
# --> 295         data_to_wrap = f(self, X, *args, **kwargs)
#     296         if isinstance(data_to_wrap, tuple):
#     297             # only wrap the first output for cross decomposition
#     298             return_tuple = (
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\shubh\OneDrive\Desktop\SOC_cyberguard\Train_data.csv")
print(df.head())
df = df[df['class']=='anomaly']
print(df.head())
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# ...

# %%
# Step 0: Install scikit-learn if not already installed
try:
    import sklearn
except ModuleNotFoundError:
    import os
    os.system('pip install scikit-learn')
    import sklearn

# Step 1: Import the necessary libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Step 2: Load the dataset  # Replace with your CSV file path
data = pd.read_csv(r"C:\Users\shubh\OneDrive\Desktop\SOC_cyberguard\Train_data.csv")

# Step 3: Preprocess the data
# Drop non-numeric columns and the target column 'class' if it exists
data_numeric = data.drop(columns=['protocol_type', 'service', 'flag', 'class'])

# Encode categorical columns if necessary
label_encoders = {}
for column in ['protocol_type', 'service', 'flag']:
    le = LabelEncoder()
    data[column] = le.fit_transform(data[column])
    label_encoders[column] = le

# Combine numeric and encoded categorical columns
data_preprocessed = pd.concat([data_numeric, data[['protocol_type', 'service', 'flag']]], axis=1)

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_preprocessed)

# Step 4: Apply K-means clustering
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(scaled_data)
labels = kmeans.labels_

# Step 5: Analyze the clusters
# Add the cluster labels to the original data
data['Cluster'] = labels

# Assuming cluster 0 is normal and cluster 1 is anomaly
# You may need to check the characteristics of each cluster to confirm this assumption
data['Anomaly'] = data['Cluster'].apply(lambda x: 'Anomaly' if x == 1 else 'Normal')

# Step 6: Visualize the clusters using PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_data)
plt.figure(figsize=(10, 7))
plt.scatter(principal_components[:, 0], principal_components[:, 1], c=labels, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering of Network Packets')
plt.show()

# Print out the first few rows to see the results
print(data.head())
data.to_csv('hello.csv')

print(principal_components)

# Save the preprocessed data with cluster and anomaly labels to a new CSV file
output_file_path = 'path_to_save_preprocessed_data.csv'  # Replace with your desired output path
data.to_csv(output_file_path, index=False)
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              1       19     9        491          0     0
# 1         0              2       41     9        146          0     0
# 2         0              1       46     5          0          0     0
# 3         0              1       22     9        232       8153     0
# 4         0              1       22     9        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_diff_srv_rate  \
# 0               0       0    0  ...                    0.03
# 1               0       0    0  ...                    0.60
# 2               0       0    0  ...                    0.05
# 3               0       0    0  ...                    0.00
# 4               0       0    0  ...                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# ...

# %%
# Step 0: Install scikit-learn if not already installed
try:
    import sklearn
except ModuleNotFoundError:
    import os
    os.system('pip install scikit-learn')
    import sklearn

# Step 1: Import the necessary libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Step 2: Load the dataset  # Replace with your CSV file path
data = pd.read_csv(r"C:\Users\shubh\OneDrive\Desktop\SOC_cyberguard\Train_data.csv")

# Step 3: Preprocess the data
# Drop non-numeric columns except 'class'
data_numeric = data.drop(columns=['protocol_type', 'service', 'flag'])

# Encode categorical columns if necessary
label_encoders = {}
for column in ['protocol_type', 'service', 'flag']:
    le = LabelEncoder()
    data[column] = le.fit_transform(data[column])
    label_encoders[column] = le

# Combine numeric and encoded categorical columns
data_preprocessed = pd.concat([data_numeric.drop(columns=['class']), data[['protocol_type', 'service', 'flag']]], axis=1)
print(data_preprocessed) 

# Standardize the data and scaling it because PCA doesnt work otherwise
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_preprocessed)

# Step 4: Apply K-means clustering
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(scaled_data)
labels = kmeans.labels_

# Step 5: Analyze the clusters
# Add the cluster labels to the original data
data['Cluster'] = labels

# Assuming cluster 0 is normal and cluster 1 is anomaly
# You may need to check the characteristics of each cluster to confirm this 

# Step 6: Visualize the clusters using PCA
pca = PCA(n_components=10)
principal_components = pca.fit_transform(scaled_data)

# Use the 'class' column to color the points
color_mapping = {'normal': 'blue', 'anomaly': 'yellow'}
colors = data['class'].map(color_mapping)

plt.figure(figsize=(10, 7))
plt.scatter(principal_components[:, 0], principal_components[:, 1], c=colors)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering of Network Packets')
plt.show()

# Print out the first few rows to see the results
print(data.head())
data.to_csv('hello.csv')

print(principal_components)

# Save the preprocessed data with cluster and anomaly labels to a new CSV file
output_file_path = 'path_to_save_preprocessed_data.csv'  # Replace with your desired output path
data.to_csv(output_file_path, index=False)
# Out:
#        duration  src_bytes  dst_bytes  land  wrong_fragment  urgent  hot  \
# 0             0        491          0     0               0       0    0
# 1             0        146          0     0               0       0    0
# 2             0          0          0     0               0       0    0
# 3             0        232       8153     0               0       0    0
# 4             0        199        420     0               0       0    0
# ...         ...        ...        ...   ...             ...     ...  ...
# 25187         0          0          0     0               0       0    0
# 25188         0        334          0     0               0       0    0
# 25189         0          0          0     0               0       0    0
# 25190         0          0          0     0               0       0    0
# 25191         0          0          0     0               0       0    0
#
#        num_failed_logins  logged_in  num_compromised  ...  \
# ...

# %%
# Step 0: Install scikit-learn if not already installed
try:
    import sklearn
except ModuleNotFoundError:
    import os
    os.system('pip install scikit-learn')
    import sklearn
    import joblib

# Step 1: Import the necessary libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import joblib

# Step 2: Load the dataset  # Replace with your CSV file path
data = pd.read_csv(r"C:\Users\shubh\OneDrive\Desktop\SOC_cyberguard\Train_data.csv")

# Step 3: Preprocess the data
# Drop non-numeric columns except 'class'
data_numeric = data.drop(columns=['protocol_type', 'service', 'flag'])

# Encode categorical columns if necessary
label_encoders = {}
for column in ['protocol_type', 'service', 'flag']:
    le = LabelEncoder()
    data[column] = le.fit_transform(data[column])
    label_encoders[column] = le

# Combine numeric and encoded categorical columns
data_preprocessed = pd.concat([data_numeric.drop(columns=['class']), data[['protocol_type', 'service', 'flag']]], axis=1)

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_preprocessed)

# Step 4: Apply K-means clustering
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(scaled_data)
labels = kmeans.labels_

# Step 5: Analyze the clusters
# Add the cluster labels to the original data
data['Cluster'] = labels

# Assuming cluster 0 is normal and cluster 1 is anomaly
# You may need to check the characteristics of each cluster to confirm this 

# Step 6: Visualize the clusters using PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_data)

# Use the 'class' column to color the points
color_mapping = {'normal': 'blue', 'anomaly': 'yellow'}
colors = data['class'].map(color_mapping)

plt.figure(figsize=(10, 7))
plt.scatter(principal_components[:, 0], principal_components[:, 1], c=colors)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering of Network Packets')
plt.show()

# Print out the first few rows to see the results
print(data.head())
data.to_csv('hello.csv')

print(principal_components)

# Save the preprocessed data with cluster and anomaly labels to a new CSV file
output_file_path = 'path_to_save_preprocessed_data.csv'  # Replace with your desired output path
data.to_csv(output_file_path, index=False)

# Save the scaler and KMeans model to disk
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(kmeans, 'kmeans.pkl')
joblib.dump(label_encoders, 'label_encoders.pkl')


# Step 0: Install scikit-learn if not already installed
try:
    import sklearn
except ModuleNotFoundError:
    import os
    os.system('pip install scikit-learn')
    import sklearn
    import joblib

# Step 1: Import the necessary libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import KMeans
import joblib

# Load the scaler, KMeans model, and label encoders from disk
scaler = joblib.load('scaler.pkl')
kmeans = joblib.load('kmeans.pkl')
label_encoders = joblib.load('label_encoders.pkl')

# Load the test dataset  # Replace with your CSV file path
test_data = pd.read_csv(r"C:\Users\shubh\OneDrive\Desktop\SOC_cyberguard\Test_data.csv")

# Preprocess the test data
# Drop non-numeric columns except 'class' if it exists
test_data_numeric = test_data.drop(columns=['protocol_type', 'service', 'flag'])

# Encode categorical columns if necessary
for column in ['protocol_type', 'service', 'flag']:
    test_data[column] = label_encoders[column].transform(test_data[column])

# Combine numeric and encoded categorical columns
test_data_preprocessed = pd.concat([test_data_numeric.drop(columns=['class'], errors='ignore'), test_data[['protocol_type', 'service', 'flag']]], axis=1)

# Standardize the test data
scaled_test_data = scaler.transform(test_data_preprocessed)

# Predict clusters for the test data
test_labels = kmeans.predict(scaled_test_data)

# Add the cluster labels to the original test data
test_data['Cluster'] = test_labels

# Assuming cluster 0 is normal and cluster 1 is anomaly
# You may need to check the characteristics of each cluster to confirm this assumption
test_data['Anomaly'] = test_data['Cluster'].apply(lambda x: 'Anomaly' if x == 1 else 'Normal')

# Print out the first few rows to see the results
print(test_data.head())

# Save the test data with cluster and anomaly labels to a new CSV file
test_output_file_path = 'path_to_save_test_data_results.csv'  # Replace with your desired output path
test_data.to_csv(test_output_file_path, index=False)
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              1       19     9        491          0     0
# 1         0              2       41     9        146          0     0
# 2         0              1       46     5          0          0     0
# 3         0              1       22     9        232       8153     0
# 4         0              1       22     9        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# ...

# %%
# Step 0: Install scikit-learn if not already installed
try:
    import sklearn
except ModuleNotFoundError:
    import os
    os.system('pip install scikit-learn')
    import sklearn
    import joblib

# Step 1: Import the necessary libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
import joblib

# Step 2: Load the dataset  # Replace with your CSV file path
data = pd.read_csv(r"C:\Users\shubh\OneDrive\Desktop\SOC_cyberguard\Train_data.csv")

# Step 3: Preprocess the data
# Drop non-numeric columns except 'class'
data_numeric = data.drop(columns=['protocol_type', 'service', 'flag'])

# Encode categorical columns if necessary
label_encoders = {}
for column in ['protocol_type', 'service', 'flag']:
    le = LabelEncoder()
    data[column] = le.fit_transform(data[column])
    label_encoders[column] = le

# Combine numeric and encoded categorical columns
data_preprocessed = pd.concat([data_numeric.drop(columns=['class']), data[['protocol_type', 'service', 'flag']]], axis=1)

# Extract the target variable
y = data['class'].map({'normal': 0, 'anomaly': 1})

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_preprocessed)

# Step 4: Apply PCA for dimensionality reduction
pca = PCA(n_components=10)
principal_components = pca.fit_transform(scaled_data)

# Step 5: Train logistic regression model
log_reg = LogisticRegression(random_state=42)
log_reg.fit(principal_components, y)

# Save the scaler, PCA, and logistic regression model to disk
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(pca, 'pca.pkl')
joblib.dump(log_reg, 'log_reg.pkl')
joblib.dump(label_encoders, 'label_encoders.pkl')

# Print out the first few rows to see the results
print(data.head())
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              1       19     9        491          0     0
# 1         0              2       41     9        146          0     0
# 2         0              1       46     5          0          0     0
# 3         0              1       22     9        232       8153     0
# 4         0              1       22     9        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# ...
